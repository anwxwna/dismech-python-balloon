# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
m1 = 3
m2 = 4

x = np.linspace(0,10,10)
y1 = m1*x
y2 = m2*x
y3 = y1 + y2

plt.plot(x, y1)
plt.plot(x, y2)
plt.plot(x,y3)

# %%
El =
lambda1 = p*r* (1/El)
I1 =
